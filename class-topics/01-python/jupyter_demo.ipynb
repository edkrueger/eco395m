# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # header 1
# ## header 2
# ### header 3
# #### header 4
# ##### header 5
#
# some text
#
# * a
# * b
# * c
#
# in $\frac{1}{2}$ line

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined
