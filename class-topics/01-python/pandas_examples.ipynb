# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [
        [1, 2, 3],
        [4, 5, 6],
        [7, 8 , 9]
    ]
)

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df[0]
# Out:
# 0    1
# 1    4
# 2    7
# Name: 0, dtype: int64

# %%
df.loc[0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: 0, dtype: int64

# %%
df.loc[1, 1]
# Out:
# 5

# %%
df.loc[1:3, 1:3]
# Out:
#    1  2
# 1  5  6
# 2  8  9
